# %% [markdown]
# <h3 align="center" style="height:1123px;font-family: 'Times New Roman', Times, serif:"><b>
#
#     LAPORAN PRAKTIKUM
#
#     ALGORITMA & PEMOGRAMAN
#
#     “TIPE DATA DAN VARIABEL”
#
#     Disusun Oleh :
#
#     AGUNG FIRMANSYAH
#
#     2611533011
#
#     Dosen Pengampu:
#
#     Wahyudi.DR.. S.T.M.T
#
#     Asisten Praktikum:
#
#     SHERLY SUKMADIRA
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
#     FAKULTAS TEKNOLOGI INFORMASI
#
#     DEPARTEMEN INFORMATIKA
#
#     UNIVERSITAS ANDALAS
#
#     2026
#
# </b></h3>

# %% [markdown]
# ---
# <div style="height:1123px;font-family:'Times New Roman', Times, serif; font-size: 18px;">
# <h1 align="center"><b>KATA PENGANTAR</b></h1>
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum tentang tipe data dan variabel yang telah dilaksanakan sebagai pertemuan ke-2 untuk mata kuliah Praktikum Struktur Data. Praktikum ini berfokus pada tipe data yang digunakan untuk menentukan jenis nilai program Int, Float, Komplek, Boolean, Konstanta, Dan String
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami berbagai jenis tipe data dan cara menggunakan variabel dalam Python serta mampu menerapkannya dalam pembuatan program sederhana. Tipe data adalah jenis data yang digunakan dalam program, seperti angka, teks, atau nilai benar dan salah. Tipe data membantu komputer mengetahui cara mengolah data tersebut. Variabel adalah tempat untuk menyimpan data dalam program. Data yang disimpan dalam variabel bisa digunakan kembali atau diubah sesuai kebutuhan.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# <div align="right" style="margin-left:-30px;">
# Padang, 2026
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# Agung Firmansyah
# <br>
# 2611533011
# </div>
# </div>

# %% [markdown]
# ---
# <div style="height:1123px;font-family:'Times New Roman', Times, serif; font-size: 18px;">
# <h1 align="center"><b>BAB I <br> PENDAHULUAN</b></h1>
#
# ## 1.1 Latar Belakang
# Dalam pemrograman, data merupakan bagian penting yang digunakan untuk menjalankan suatu program. Data yang digunakan bisa berupa angka, teks, maupun nilai benar atau salah. Agar data dapat digunakan dengan baik, kita perlu memahami tipe data dan variabel. Tipe data digunakan untuk menentukan jenis data yang digunakan dalam program. Sedangkan variabel digunakan untuk menyimpan data agar bisa digunakan kembali atau diubah saat program dijalankan. Pemahaman tentang tipe data dan variabel merupakan dasar yang penting bagi mahasiswa dalam belajar pemrograman. Dengan memahami keduanya, mahasiswa akan lebih mudah membuat program sederhana, mengolah data, dan memahami cara kerja suatu program.
#
# ## 1.2 Tujuan
# 1. Mengetahui pengertian dan fungsi tipe data serta variabel.
# 2. Memahami jenis-jenis tipe data dalam Python.
# 3. Mengetahui cara membuat dan menggunakan variabel.
# 4. Mampu menggunakan tipe data dan variabel dalam membuat program sederhana.
# 5. Memahami cara menyimpan dan mengolah data dalam program
# ## 1.3 Manfaat
# 1. Mahasiswa memahami dasar-dasar pemrograman dengan lebih mudah.
# 2. Mahasiswa meningkatkan kemampuan berpikir logis dalam menyelesaikan masalah.
# 3. Mahasiswa mampu membuat program sederhana menggunakan Python.
# 4. Mahasiswa memahami cara menyimpan dan mengolah data dalam program.
# 5. Mahasiswa menjadi bekal untuk mempelajari pemrograman lebih lanjut.
# </div>

# %% [markdown]
# ---
# <div style=font-family:'Times New Roman', Times, serif; font-size: 18px;">
# <h1 align="center"><b>BAB II<br>PEMBAHASAN</b></h1>
#
# ## 2.1 Dasar Teori
# Pengenalan tentang tipe data dan variabel
#
# 1. Int (Integer)<br>
# Int adalah tipe data yang digunakan untuk menyimpan bilangan bulat, baik bilangan positif, negatif, maupun nol. Tipe data ini biasanya digunakan dalam perhitungan yang tidak membutuhkan angka desimal.
#
# 2. Float<br>
# Float adalah tipe data yang digunakan untuk menyimpan bilangan yang memiliki angka desimal. Tipe data ini banyak digunakan dalam perhitungan yang membutuhkan hasil yang lebih tepat.
#
# 3. Komplek (Complex)<br>
# Complex adalah tipe data yang digunakan untuk menyimpan bilangan kompleks, yaitu bilangan yang memiliki bagian nyata dan bagian imajiner. Tipe data ini biasanya digunakan dalam perhitungan matematika atau bidang tertentu yang membutuhkan bilangan kompleks.
#
# 4. Boolean<br>
# Boolean adalah tipe data yang hanya memiliki dua nilai, yaitu benar (True) atau salah (False). Tipe data ini biasanya digunakan untuk menentukan suatu kondisi dalam program.
#
# 5. Konstanta<br>
# Konstanta adalah nilai yang tetap dan tidak seharusnya berubah selama program dijalankan. Konstanta digunakan untuk menyimpan nilai yang memang ingin dipertahankan agar tidak berubah.
#
# 6. String<br>
# String adalah tipe data yang digunakan untuk menyimpan teks atau kumpulan karakter. String dapat berupa huruf, kata, kalimat, angka yang dianggap sebagai teks, maupun simbol.
# </div>

# %% [markdown]
# <div style=font-family:'Times New Roman', Times, serif; font-size: 18px;">
#
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "String_2611533011"
# </div>

# %%
# Buat file dengan nama string String_2611533011.py
# nama variabel ditambah 4 digit terakhir contoh: nama_3011
# ganti programnya dan data masing2
nama = "Agung_3011"
jenis_kelamin = "L"
alamat = """ 
Kampus Unand
Kec.Kuranji
Kota Padang
"""
agama = "islam"
print("Nama saya adalah: ", nama)
print("Jenis kelamin saya adalah: ", jenis_kelamin)
print("Alamat saya adalah: ", alamat)
print("Agama saya adalah: ", agama)
# Out:
# Nama saya adalah:  Agung_3011
# Jenis kelamin saya adalah:  L
# Alamat saya adalah:
# Kampus Unand
# Kec.Kuranji
# Kota Padang
#
# Agama saya adalah:  islam

# %% [markdown]
# <div style=font-family:'Times New Roman', Times, serif; font-size: 18px;">
# Penjelasan:
#
# 1. Deklarasi nama_3011 = "Agung" sebagai string
# 2. Deklarasi jenis_kelamin_3011 = 'L' sebagai string
# 3. Deklarasi alamat_3011 = """Kampus Unand, Kec.Kuranji, Kota Padang""" sebagai string
# 4. Deklarasi agama_3011 = "Islam" sebagai string
# 5. Cetak ("Nama saya adalah: ", nama_3011)
# 6. Cetak ("Jenis kelamin saya adalah: ", jenis_kelamin_3011)
# 7. Cetak ("Alamat saya adalah: ", alamat_3011)
# 8. Cetak ("Agama saya adalah: ", agama_3011)
# </div>

# %% [markdown]
# <div style=font-family:'Times New Roman', Times, serif; font-size: 18px;">
#
# ### 2.2.2 Program "Numerik_2611533011"
# </div>

# %%
#create a variable with integer value.
a_3011=100
print("The type of variable having value", a_3011, " is" , type(a_3011))

#create a variable with float value.
b_3011=10.2345
print("The type of variable having value", b_3011, " is" , type(b_3011))

#create a variable with complex value.
c_3011=100+3j
print("The type of variable having value", c_3011, " is", type(c_3011))
# Out:
# The type of variable having value 100  is <class 'int'>
# The type of variable having value 10.2345  is <class 'float'>
# The type of variable having value (100+3j)  is <class 'complex'>

# %% [markdown]
# <div style=font-family:'Times New Roman', Times, serif; font-size: 18px;">
# Penjelasan:
#
# 1. Deklarasi a_3011 dengan nilai 100 sebagai integer.
# 2. Cetak "The type of variable having value",a_3011,"is",type(a_3011) dengan type() digunakan untuk mengetahui tipe variabel dari a_3011.
# 3. Deklarasi b_3011 dengan nilai 10.2345 sebagai float.
# 4. Cetak "The type of variable having value",b_3011,"is",type(b_3011) dengan type() digunakan untuk mengetahui tipe variabel dari b_3011.
# 5. Deklarasi c_3011 dengan nilai (100 + 3j) sebagai komplek.
# 6. Cetak "The type of variable having value",c_3011,"is",type(c_3011) dengan type() digunakan untuk mengetahui tipe variabel dari c_3011.
#
# ### 2.2.3 Program "Boolean_2611533011"
# </div>

# %%
# Buat file dengan nama Boolean_2611533011
# Nama variabel ditambah 4 digit nim terakhir contoh: nilai_1234
# Deklarasi variabel dengan tipe data Boolean
is_lulus_3011 = True
is_cumlaude_3011 = True

# Menggunakan Boolean
nilai_3011 = 85
batas_lulus_3011 = 75

# Menantukan nilai Boolean dari kondisi
status_kelulusan_3011 = nilai_3011 >= batas_lulus_3011 # Hasilnya akan True

print("=== Check Kelulusan ===")
print("Nilai: ",nilai_3011)
print("Apakah lulus?: ",status_kelulusan_3011)
if is_lulus_3011 and is_cumlaude_3011:
    print("Selamat, Anda lulus dengan predikat Cum Laude!")
# Out:
# === Check Kelulusan ===
# Nilai:  85
# Apakah lulus?:  True
# Selamat, Anda lulus dengan predikat Cum Laude!

# %% [markdown]
# <div style=font-family:'Times New Roman', Times, serif; font-size: 18px;">
# Penjelasan:
#
# 1. Deklarasi is_lulus_3011 = True sebagai boolean
# 2. Deklarasi is_cumlaude_3011 = True sebagai boolean
# 3. Deklarasi nilai_3011 = 85 sebagai integer
# 5. Deklarasi batas_lulus_3011 = 75 sebagai integer
# 6. Deklarasi status_kelulusan_3011 = nilai_3011 >= batas_lulus_3011 sebagai boolean
# 7. Cetak ("=== Check Kelulusan ===")
# 8. Cetak ("Nilai: ",nilai_3011)
# 9. Cetak ("Apakah lulus?: ",status_kelulusan_3011)
# 10. Jika is_lulus_3011 dan is_cumlaude_3011 bernilai benar cetak ("Selamat, Anda lulus dengan predikat Cum Laude!")
#
# ### 2.2.4 Program Input_2611533011
# </div>

# %%
# Buat file dengan nama Input_2611533011.py
# Buat Program untuk menghitung luas persegi panjang
# Nama variabel ditambah 4 digit nimm terakhir contoh: nama_3011
# Program ini menggunakan fungsi input() untuk meminta pengguna
# memasukan nilai panjang dan lebar persegi panjang
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
panjang_3011 = input('Masukkan nilai panjang: ')
lebar_3011 = input('Masukkan nilai lebar: ')
luas_3011 = int(panjang_3011) * int(lebar_3011)
print("Luas =", luas_3011)
# Out:
# Luas = 20

# %% [markdown]
# <div style=font-family:'Times New Roman', Times, serif; font-size: 18px;">
# Penjelasan:
#
# 1. Input nilai panjang_3011
# 2. Input nilai lebar_3011
# 3. Nilai luas_3011 = int(panjang_3011) * int(lebar_3011)
# 4. Cetak ("Luas = ",luas_3011)
#
# ### 2.2.5 Program Konstanta_2611533011
# </div>

# %%
# Buat file dengan nama Konstanta_2611533011
# Program ini menggunakan konstanta untuk menghitun luas lingkaran
# nama variabel ditambah 4 digit nim terakhir contoh: jari_3011
from typing import Final
PI: Final = 3.14
print("pi: %f" % PI)
jari_3011 = float(input('Masukkan jari-jari lingkaran: '))
luas_3011 = PI * jari_3011 * jari_3011
print("Luas lingkaran dengan jari-jari %.2f adalah %.2f" % (jari_3011, luas_3011))
# Out:
# pi: 3.140000
# Luas lingkaran dengan jari-jari 4.00 adalah 50.24

# %% [markdown]
# <div style=font-family:'Times New Roman', Times, serif; font-size: 18px;">
# Penjelasan:
#
# 1. Pemanggilan Final dari library typing from typing import Final
# 2. Deklarasi PI: Final = 3.14 sebagai konstanta
# 3. Cetak ("Pi: %f" % (PI))
# 4. Nilai jari_3011 = float(input("Masukkan nilai jari-jari: "))
# 5. Nilai luas_3011 = PI * jari_3011
# 6. Cetak ("Luas lingkaran dengan jari-jari %.2f adalah %.2f" % (jari_3011,luas_3011))
# </div>

# %% [markdown]
# ---
# <div style="height:1123px;font-family:'Times New Roman', Times, serif; font-size: 18px;">
#
# <h1 align="center"><b>BAB III<br>KESIMPULAN</b></h1>
#
# Berdasarkan pembelajaran tentang tipe data dan variabel dalam Python, dapat disimpulkan bahwa tipe data digunakan untuk menentukan jenis nilai yang dapat disimpan dan diolah oleh program. Beberapa tipe data yang dipelajari yaitu int untuk bilangan bulat, float untuk bilangan desimal, complex untuk bilangan kompleks, string untuk teks, dan bool untuk nilai benar atau salah. Selain itu, variabel digunakan sebagai tempat untuk menyimpan data yang dapat digunakan kembali dalam program, sedangkan konstanta digunakan untuk menyimpan nilai yang seharusnya tetap. Penggunaan input() memungkinkan program menerima data dari pengguna sehingga program menjadi lebih interaktif. Dengan memahami tipe data, variabel, konstanta, dan input, pembuatan program Python menjadi lebih terstruktur dan mudah dipahami
# </div>

# %% [markdown]
# ---
# <div style=font-family:'Times New Roman', Times, serif; font-size: 18px;">
#
# <h1 align="center"><b>DAFTAR PUSTAKA</b></h1>
#
# 1. Python Software Foundation. (2026). Built-in Types — Python 3.14.7 documentation.
# https://docs.python.org/3/library/stdtypes.html
#
# 2. Python Software Foundation. (2026). The Python Language Reference — Python 3.14.7 documentation.
# https://docs.python.org/3/reference/
#
# 3. Python Software Foundation. (2026). Built-in Functions — Python 3.14.7 documentation.
# https://docs.python.org/3/library/functions.html
#
# 4. Python Software Foundation. (2026). Tipe Data — Dokumentasi Python 3.14.7.
# https://docs.python.org/id/3/library/datatypes.html
# </div>
