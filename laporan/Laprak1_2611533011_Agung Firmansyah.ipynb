# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“JUDUL MODUL PRAKTIKUM”**
#
# **Disusun Oleh :**
#
# **AGUNG FIRMANSYAH**
#
# **2611533011**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **SHERLY SUKMADIRA**
#
#
#  <img src="images\logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# <h1 align="center"> KATA PENGANTAR </h1>
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum pengenalan Python, VS Code, dan koneksi ke Github yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Struktur Data. Praktikum ini berfokus pada pengenalan Python dan pembuatan akun Github
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep Python dan Github pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# <div align="right" style="margin-left:-30px;">
# Padang, 2026
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# Agung Firmansyah
# <br>
# 2611533011
# </div>

# %% [markdown]
# ---
# <h1 align="center"> BAB I <br> PENDAHULUAN </h1>
#
# ## 1.1 Latar Belakang
# Perkembangan teknologi informasi yang semakin pesat membuat kemampuan pemrograman menjadi salah satu keterampilan yang penting dalam berbagai bidang. Salah satu bahasa pemrograman yang banyak digunakan adalah Python karena memiliki sintaks yang sederhana, mudah dipahami, serta dapat diterapkan dalam berbagai kebutuhan seperti pengolahan data, pembuatan aplikasi, otomatisasi, dan pengembangan sistem.
#  Dalam proses pengembangan program, diperlukan sebuah perangkat yang dapat membantu programmer menulis, menjalankan, serta memperbaiki kode dengan lebih mudah. Salah satu perangkat yang banyak digunakan adalah Visual Studio Code (VS Code). VS Code merupakan code editor yang menyediakan berbagai fitur untuk mendukung proses pemrograman, seperti penulisan kode, debugging, penggunaan ekstensi, serta integrasi dengan berbagai bahasa pemrograman termasuk Python. Penggunaan VS Code dapat membuat proses pembuatan dan pengembangan program menjadi lebih terstruktur dan efisien. platform yang banyak digunakan untuk kebutuhan tersebut adalah GitHub. GitHub merupakan platform yang digunakan untuk menyimpan, mengelola, dan membagikan kode program dengan memanfaatkan sistem version control Git. Melalui GitHub, setiap perubahan kode dapat terdokumentasi dengan baik sehingga programmer dapat memantau perkembangan proyek, melakukan pencadangan kode, serta kembali ke versi sebelumnya apabila terjadi kesalahan. GitHub juga mendukung kolaborasi sehingga beberapa orang dapat mengerjakan satu proyek secara bersama-sama. Dengan demikian, kegiatan pengenalan Python, VS Code, dan GitHub pada real project diharapkan dapat meningkatkan kemampuan pemrograman sekaligus memberikan pemahaman mengenai cara kerja pengembangan perangkat lunak yang lebih terstruktur. Pengalaman tersebut juga dapat menjadi dasar dalam mengerjakan proyek yang lebih kompleks dan membangun keterampilan yang sesuai dengan kebutuhan dunia kerja di bidang teknologi informasi.
#
# ## 1.2 Tujuan
# 1. Mampu melakukan instalasi Visual Studio Code (VS Code) sebagai code editor untuk menulis dan menjalankan suatu program.
# 2. Mampu melakukan instalasi Python beserta pengaturan environment nya agar dapat dijalankan melalui VS Code.
# 3. Mampu membuat dan melakukan registrasi akun Github sebagai platform version control dan kolaborasi.
# 4. Mampu menulis dan menjalankan program Python sederhana menggunakan fungsi print().
#
# ## 1.3 Manfaat
# 1. Mahasiswa mampu menggunakan Visual Studio Code (VS Code)
# 2. Mahasiswa dapat memahami dasar penggunaan Python sebagai dasar pemrograman
# 3. Mahasiswa memiliki akun Github yang dapat digunakan sebagai tempat penyimpanan dan dokumentasi code program secara online

# %% [markdown]
# ---
# <h1 align="center"> BAB II <br>PEMBAHASAN </h1>
#
# ## 2.1 Dasar Teori
# Pengenalan tentang Python, VS Code, Github
#
# 1. Visual Studio Code
# <br>(VS Code) adalah aplikasi code editor yang digunakan untuk menulis, mengedit, dan menjalankan program. VS Code mendukung berbagai bahasa pemrograman, termasuk Python. Aplikasi ini memiliki fitur seperti debugging, terminal, ekstensi, serta integrasi dengan Git dan GitHub, sehingga memudahkan proses pembuatan dan pengelolaan proyek.
# 2. Python
# <br>Python adalah bahasa pemrograman yang digunakan untuk memberikan perintah kepada komputer agar melakukan sesuatu.
# Python memiliki cara penulisan yang sederhana dan mudah dipahami, sehingga cocok untuk orang yang baru belajar pemrograman. Dengan Python, kita bisa membuat berbagai program, seperti mengolah data, membuat aplikasi, menghitung sesuatu, dan mengotomatisasi pekerjaan. contoh print("Hello World")
# 3. GitHub
# <br>Github adalah platform yang digunakan untuk menyimpan, mengelola, dan membagikan kode program secara online. GitHub membantu programmer menyimpan proyek dengan aman dan mencatat setiap perubahan yang dilakukan pada kode. GitHub juga dapat digunakan untuk bekerja sama dalam sebuah proyek. Beberapa orang dapat mengerjakan proyek yang sama tanpa harus mengirim file secara manual satu per satu.
# 4. Repository
# <br>Repository adalah tempat untuk menyimpan dan mengelola file dalam sebuah project. Repository dapat menyimpan kode, dokumen, serta riwayat perubahan project.
# 5. Commit dan Push
# <br>Commit adalah proses untuk menyimpan perubahan pada project ke dalam Git. Commit biasanya diberikan pesan agar kita tahu perubahan apa yang telah dilakukan. Push adalah proses untuk mengirim atau mengupload hasil commit dari komputer ke repository yang ada di GitHub.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "A_2611533011"

# %%
# Program Pertama
"""
Komentar
dua baris atau lebih
pertemuan 1 praktikum alpro
"""
print("hello world")
print()
print("program ini menghasilkan")
print("empat baris output")
print("/ \\ // \\\\ /// \\\\\\")
print("program ini" + " dibuat oleh a/n" + " Agung Firmansyah 2611533011")
# Out:
# Running cells with '.venv-1 (3.14.7.final.0) (Python 3.14.7)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/agung/OneDrive/KULIAH AGUNG/2026_prakalpro_A_2611533011/laporan/.venv-1/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# **Penjelasan :**
# 1. Baris 1 berfungsi untuk comment dengan simbol '#' sebagai awalan comment dalam bahasa python
# 2. Baris 2-6 berfungsi untuk menyimpan string dengan banyak baris """ """ sebagai simbol
# 3. Baris 7-12 berfungsi mencetak program dengan print() sebagai syntax
# 4. Program ini dijalankan melalui terminal atau fitur Run pada VS Code
# ### 2.2.2 Membuat Repository Github
#
# setelah program dibuat dan dilakukan uji coba pada VS Code, proyek dapat dihubungkan dengan Github. Repository digunakan untuk menyimpan kode program secara daring.
#
# Tahapan yang dilakukan yaitu:
#
# 1. Membuat Repository baru pada Github.
# 2. Membuka folder proyek menggunakan VS Code
# 3. Membuka terminal pada VS Code
# 4. Menginisialisasi Git pada folder proyek
# 5. Menambahkan file ke dalam staging
# 6. Membuat commit
# 7. Menghubungkan repository lokal dengan repository Github
# 8. Melakukan push untuk mengunggah kode ke Github.
#
# contoh perintah yang digunakan adalah:

# %%
git init
git add .
git commit -m "initial commit"
git branch -M main
git remote add origin https://github.com./username/nama-repository.git
git push -u origin main

# %% [markdown]
# Penjelasan:
#
# 1. git init
# digunakan untuk memulai Git di dalam folder project.
# 2. git add .
# digunakan untuk memasukkan semua file project ke Git.
# 3. git commit
# digunakan untuk menyimpan perubahan yang sudah dibuat.
# 4. git branch
# Untuk membuat main sebagai branch utama.
# 5. git remote add origin
# digunakan untuk menghubungkan project dengan repository GitHub.
# 6. git push
# digunakan untuk mengupload project ke GitHub.

# %% [markdown]
# ---
# <h1 align="center"> BAB III <br> KESIMPULAN </h1>
#
# Berdasarkan kegiatan yang telah dilakukan, dapat disimpulkan bahwa Python merupakan bahasa pemrograman yang mudah dipahami dan dapat digunakan untuk membuat berbagai program. VS Code digunakan sebagai tempat untuk menulis, menjalankan, dan mengembangkan kode Python. Repository berfungsi sebagai tempat untuk menyimpan dan mengelola file serta kode dalam sebuah project. Sementara itu, GitHub digunakan untuk menyimpan repository secara online sehingga project dapat diakses, dikelola, dan dibagikan dengan orang lain. Keempatnya saling berhubungan dan dapat membantu mahasiswa dalam membuat serta mengelola real project dengan lebih teratur.

# %% [markdown]
# ---
# <h1 align="center"> DAFTAR PUSTAKA </h1>
#
# 1. Python SOftware Foundation. (2026). The Python Tutorial. Python Documentation. https://docs.python.org/3/tutorial/
#
# 2. Microsoft. (2026). Phyton in Visual Studio Code. Visual Studio Code Documentation. https://code.visualstudio.com/docs/language/phyton
#
# 3. GitHub. (2026). About repositories. GitHub Docs. https://docs.github.com/en/repositories/creating-and-managing-repositories/about-repositories
#
# 4. GitHub. (2026). About remote repositories. GitHub Docs. https://docs.github.com/en/get-started/git-basics/about-remote-repositories
